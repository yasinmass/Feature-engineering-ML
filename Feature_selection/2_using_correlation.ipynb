# %% [markdown]
# ## 2.Feature selection - Correlation

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as se

# %%
benz_data=pd.read_csv("type_of_encoding/dataset/benz.csv")
benz
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 benz_data=pd.read_csv("benz.csv")
# ----> 2 benz
#
# NameError: name 'benz' is not defined
